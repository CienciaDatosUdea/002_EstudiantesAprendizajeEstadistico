# %%
# !pip install numpy==1.24.4
# Out:
# Requirement already satisfied: numpy==1.24.4 in /usr/local/lib/python3.11/dist-packages (1.24.4)

# %% [markdown]
# <a href="https://colab.research.google.com/github/CienciaDatosUdea/002_EstudiantesAprendizajeEstadistico/blob/main/semestre2025-1/Laboratorios/Laboratorio_01_pandas_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tipo de dato de tiempo en Pandas
#En este ejemplo vamos a crear una serie de tiempo de un mes cada dia cada hora
import pandas as pd
from datetime import datetime
import numpy as np

# range_date
rd = pd.date_range(start ='1/1/2025', end ='2/1/2025', freq ='h')
print(rd)
print(type(rd[2]))
print(len(rd))
# Out:
# DatetimeIndex(['2025-01-01 00:00:00', '2025-01-01 01:00:00',
#                '2025-01-01 02:00:00', '2025-01-01 03:00:00',
#                '2025-01-01 04:00:00', '2025-01-01 05:00:00',
#                '2025-01-01 06:00:00', '2025-01-01 07:00:00',
#                '2025-01-01 08:00:00', '2025-01-01 09:00:00',
#                ...
#                '2025-01-31 15:00:00', '2025-01-31 16:00:00',
#                '2025-01-31 17:00:00', '2025-01-31 18:00:00',
#                '2025-01-31 19:00:00', '2025-01-31 20:00:00',
#                '2025-01-31 21:00:00', '2025-01-31 22:00:00',
#                '2025-01-31 23:00:00', '2025-02-01 00:00:00'],
#               dtype='datetime64[ns]', length=745, freq='h')
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 745

# %%
#Creamos un dataframe con una columna aleatoria y el tiempo como indice
df = pd.DataFrame(rd, columns=['datetime'])
df['data'] = np.random.randint(0, 100, size=(len(rd)))
df.set_index('datetime', inplace=True)
df.head()
df.tail()
# Out:
#                      data
# datetime
# 2025-01-31 20:00:00     0
# 2025-01-31 21:00:00    92
# 2025-01-31 22:00:00    69
# 2025-01-31 23:00:00    68
# 2025-02-01 00:00:00    13

# %%
#Podemos usar el indice como una columna de la misma manera que usamos los otros tipos
filtered_df = df.loc['2025-01-31']
print(filtered_df)
# Out:
#                      data
# datetime
# 2025-01-31 00:00:00     2
# 2025-01-31 01:00:00    22
# 2025-01-31 02:00:00    97
# 2025-01-31 03:00:00    97
# 2025-01-31 04:00:00    71
# 2025-01-31 05:00:00    11
# 2025-01-31 06:00:00    19
# 2025-01-31 07:00:00    82
# 2025-01-31 08:00:00    48
# 2025-01-31 09:00:00    17
# 2025-01-31 10:00:00    39
# 2025-01-31 11:00:00    12
# 2025-01-31 12:00:00    89
# 2025-01-31 13:00:00    64
# 2025-01-31 14:00:00    95
# 2025-01-31 15:00:00     7
# 2025-01-31 16:00:00    70
# 2025-01-31 17:00:00     5
# 2025-01-31 18:00:00    49
# 2025-01-31 19:00:00     8
# 2025-01-31 20:00:00     0
# 2025-01-31 21:00:00    92
# 2025-01-31 22:00:00    69
# 2025-01-31 23:00:00    68

# %% [markdown]
# # Laboratorio 1.0:
#
# ## Series de tiempo
#
# El siguiente [dataset](https://raw.githubusercontent.com/hernansalinas/Curso_aprendizaje_estadistico/main/datasets/Pandas_data_historical_dataEURUSD.csv) contiene información del precio del eur/usd  desde el 05/07/2022/ hasta el 12/05/2023 con periodicidad de una hora. El data frame contiene el precio de apertura, cierrre, valor más bajo cotizado, valor más alto cotizado, volumen, spread etc. Para este dataset, realizar lo siguiente:
#
#
# 1. Leer el dataset desde el github.
# 2. Definir como indice la columna time.
# 3. Obtenga información del data frame.
#
# 4. Determine si hay null, nan en el data frame.
#
# 5. Emplea la notacion Pascal Case y trabaja solo con la columa del precio de cierre del eur/usd.
#
# 6. Ahora vamos a determinar cual es la mejor distribución estadística que se ajusta a la diferencia del precio de cierre cada hora, para ello realizamos lo siguiente:
# - Determine la diferencia de precio entre horas, agregue una nueva columna llamada DiffPrice, en este punto tu dataframe debe tener solo dos columnas Close, DiffPrice y el indice debe ser el tiempo.
# - Para la nueva columna construya un histograma de los datos.
# - Determine la mejor distribucion estadística que se ajusta al histograma anterior, para ello puede emplear lo siguente:
#
#
# https://pypi.org/project/fitter/
#
# ```python
#
#
# from fitter import Fitter, get_common_distributions, get_distributions
#
# f = Fitter(data,
#            distributions=['gamma',
#                           'lognorm',
#                           "beta",
#                           "burr",
#                           "norm"])
# f.fit()
# f.summary()
# #Indentificamos la mejor distribucion con el error cuadratico medio
# f.get_best(method = 'sumsquare_error')
# #Indentificamos parametros de la distrubicion beta
# f.fitted_param["beta"]
#
# ```
#
# Con el metodo get_distributions(), podemos ver todas las distribuciones estadisticas de la libreria. Ajusta a la mejor.  Puede consultar [esta](https://medium.com/the-researchers-guide/finding-the-best-distribution-that-fits-your-data-using-pythons-fitter-library-319a5a0972e9)  página si desea ver un ejemplo.
#
#
# 7. Para el data frame, seleccionemos solo los datos del 2023.
#
# 8. El comando groupby permite agrupar los datos con la periodicidad deseada: 1 dias, 2 dias, 1 mes etc. Determina el promedio con una periodicidad de 15 dias, con periodidicidad de 1 semana, y una periodicidad de 1 mes
#
# ```python
#   df.groupby(pd.Grouper(key='time', freq='15D')).mean()
# ```
#
# 9. Para los datos asociados a los meses de 2023, construya un histograma para cada mes.  Para ello puedo emplear el metodo groupby. Notetese que si no  realiza una operación después de aplicar el metodo grouby, podrias iterar sobre dicho objeto, por ejemplo:
#
# ```python
# q=df.groupby(pd.Grouper(key='time', freq='15D'))
#
# for name, group in q:
#   print(name, group)
# ```

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Leer el dataset desde el github.
# 2. Definir como indice la columna time.

# %%
#Leer dataset y definir como indice la columna time
url = "https://raw.githubusercontent.com/hernansalinas/Curso_aprendizaje_estadistico/main/datasets/Pandas_data_historical_dataEURUSD.csv"
df = pd.read_csv(url)
df.index = df['time']
df = df.drop(columns=['time','Unnamed: 0'])
df.head()
# Out:
#                         open     high      low    close  tick_volume  spread  \
# time
# 2022-07-25 13:00:00  1.02427  1.02430  1.02145  1.02345         3927       8
# 2022-07-25 14:00:00  1.02345  1.02578  1.02288  1.02299         5344       8
# 2022-07-25 15:00:00  1.02303  1.02476  1.02230  1.02457         5524       8
# 2022-07-25 16:00:00  1.02454  1.02548  1.02355  1.02485         5234       8
# 2022-07-25 17:00:00  1.02485  1.02514  1.02030  1.02181         9031       7
#
#                      real_volume  MeanCloseOpen  Diff_Close  Diff_Open  \
# time
# 2022-07-25 13:00:00            0       1.023860    -0.00046   -0.00082
# 2022-07-25 14:00:00            0       1.023220    -0.00046   -0.00082
# 2022-07-25 15:00:00            0       1.023800     0.00158   -0.00042
# 2022-07-25 16:00:00            0       1.024695     0.00028    0.00151
# 2022-07-25 17:00:00            0       1.023330    -0.00304    0.00031
#
#                      Diff_MeanCloseOpen
# time
# 2022-07-25 13:00:00           -0.000640
# 2022-07-25 14:00:00           -0.000640
# 2022-07-25 15:00:00            0.000580
# 2022-07-25 16:00:00            0.000895
# 2022-07-25 17:00:00           -0.001365

# %% [markdown]
# 3. Obtenga información del data frame.

# %%
df.describe()
# Out:
#               open         high          low        close   tick_volume  \
# count  5000.000000  5000.000000  5000.000000  5000.000000   5000.000000
# mean      1.043891     1.044815     1.042991     1.043906   3690.249400
# std       0.041135     0.040991     0.041263     0.041135   2800.488505
# min       0.953910     0.955930     0.953570     0.953910     85.000000
# 25%       1.002718     1.003507     1.001715     1.002705   1738.750000
# 50%       1.055670     1.056795     1.054960     1.055700   2999.500000
# 75%       1.078940     1.079582     1.078222     1.078947   4861.000000
# max       1.108470     1.109530     1.108050     1.108500  23708.000000
#
#             spread  real_volume  MeanCloseOpen   Diff_Close    Diff_Open  \
# count  5000.000000       5000.0    5000.000000  5000.000000  5000.000000
# mean      8.981600          0.0       1.043898     0.000012     0.000012
# std       5.785115          0.0       0.041129     0.001400     0.001404
# min       0.000000          0.0       0.954735    -0.013970    -0.014010
# 25%       8.000000          0.0       1.002648    -0.000580    -0.000600
# 50%       8.000000          0.0       1.055712    -0.000005     0.000000
# 75%       8.000000          0.0       1.078955     0.000620     0.000612
# max     183.000000          0.0       1.108280     0.017340     0.017420
#
#        Diff_MeanCloseOpen
# count         5000.000000
# mean             0.000012
# std              0.000978
# min             -0.007260
# 25%             -0.000425
# 50%              0.000005
# 75%              0.000430
# max              0.010780

# %%
#graficar el close en funcion del tiempo
fig=plt.figure(figsize=(10,6))
plt.plot(df.index, df['close'])
plt.xlabel('Time')
plt.ylabel('Close')
plt.title('Close vs Time')
ax = plt.gca()
plt.xticks(df.index[::600], rotation=90)  # Mostrar una cada 600 valores
plt.grid()
plt.show()

# %% [markdown]
# 4. Determine si hay null o nan en el dataframe

# %%
#ver si hay nans o null
df.isna().sum()
# Out:
# open                  0
# high                  0
# low                   0
# close                 0
# tick_volume           0
# spread                0
# real_volume           0
# MeanCloseOpen         0
# Diff_Close            0
# Diff_Open             0
# Diff_MeanCloseOpen    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# open                  0
# high                  0
# low                   0
# close                 0
# tick_volume           0
# spread                0
# real_volume           0
# MeanCloseOpen         0
# Diff_Close            0
# Diff_Open             0
# Diff_MeanCloseOpen    0
# dtype: int64

# %% [markdown]
# No, no hay

# %% [markdown]
# 5. Emplea la notacion Pascal Case y trabaja solo con la columa del precio de cierre del eur/usd.

# %%
#pascal case
data = df.copy()
data.columns = [x.title().replace("_","") for x in df.columns]
data.head()
# Out:
#                         Open     High      Low    Close  TickVolume  Spread  \
# time
# 2022-07-25 13:00:00  1.02427  1.02430  1.02145  1.02345        3927       8
# 2022-07-25 14:00:00  1.02345  1.02578  1.02288  1.02299        5344       8
# 2022-07-25 15:00:00  1.02303  1.02476  1.02230  1.02457        5524       8
# 2022-07-25 16:00:00  1.02454  1.02548  1.02355  1.02485        5234       8
# 2022-07-25 17:00:00  1.02485  1.02514  1.02030  1.02181        9031       7
#
#                      RealVolume  Meancloseopen  DiffClose  DiffOpen  \
# time
# 2022-07-25 13:00:00           0       1.023860   -0.00046  -0.00082
# 2022-07-25 14:00:00           0       1.023220   -0.00046  -0.00082
# 2022-07-25 15:00:00           0       1.023800    0.00158  -0.00042
# 2022-07-25 16:00:00           0       1.024695    0.00028   0.00151
# 2022-07-25 17:00:00           0       1.023330   -0.00304   0.00031
#
#                      DiffMeancloseopen
# time
# 2022-07-25 13:00:00          -0.000640
# 2022-07-25 14:00:00          -0.000640
# 2022-07-25 15:00:00           0.000580
# 2022-07-25 16:00:00           0.000895
# 2022-07-25 17:00:00          -0.001365

# %%
close = data['Close']
close.head()
# Out:
# time
# 2022-07-25 13:00:00    1.02345
# 2022-07-25 14:00:00    1.02299
# 2022-07-25 15:00:00    1.02457
# 2022-07-25 16:00:00    1.02485
# 2022-07-25 17:00:00    1.02181
# Name: Close, dtype: float64

# %% [markdown]
# 6. Ahora vamos a determinar cual es la mejor distribución estadística que se ajusta a la diferencia del precio de cierre cada hora, para ello realizamos lo siguiente:
# - Determine la diferencia de precio entre horas, agregue una nueva columna llamada DiffPrice, en este punto tu dataframe debe tener solo dos columnas Close, DiffPrice y el indice debe ser el tiempo.
# - Para la nueva columna construya un histograma de los datos.
# - Determine la mejor distribucion estadística que se ajusta al histograma anterior, para ello puede emplear lo siguente:

# %%
data['DiffPrice'] = data['Close'].diff()
data.drop(data.index[0], inplace=True)

df1 = data[['Close','DiffPrice']]
df1.head()
# Out:
#                        Close  DiffPrice
# time
# 2022-07-25 14:00:00  1.02299   -0.00046
# 2022-07-25 15:00:00  1.02457    0.00158
# 2022-07-25 16:00:00  1.02485    0.00028
# 2022-07-25 17:00:00  1.02181   -0.00304
# 2022-07-25 18:00:00  1.02099   -0.00082

# %%
#graficar diff vs t
fig=plt.figure(figsize=(10,6))
plt.plot(df1.index, df1['DiffPrice'])
plt.xlabel('Time')
plt.ylabel('DiffPrice')
plt.title('DiffPrice vs Time')
plt.xticks(df.index[::600], rotation=90)  # Mostrar una cada 600 valores
plt.grid()
plt.show()

# %%
plt.hist(df1['DiffPrice'], bins=100,color="orangered")
plt.xlabel('DiffPrice')
plt.ylabel('Frequency')
plt.title('Histogram of DiffPrice')
plt.grid()
plt.show()

# %%
# !pip -q install fitter
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.7 MB/s eta 0:00:00

# %%
from fitter import Fitter, get_common_distributions, get_distributions

# %%
f = Fitter(df1['DiffPrice'],
           distributions=get_common_distributions())
f.fit()
f.summary()
# Indentificamos la mejor distribucion con el error cuadratico medio
f.get_best(method = 'sumsquare_error')
# Out:
# {'cauchy': {'loc': -3.886416787281632e-06, 'scale': 0.0005716470285645184}}

# %%
f.summary()
# Out:
#           sumsquare_error          aic          bic  kl_div  ks_statistic  \
# cauchy       23122.545603  -311.443279  -298.409293     inf      0.042450
# lognorm     106500.661168  3074.521081  3094.072060     inf      0.091597
# norm        106744.023571  3180.994184  3194.028170     inf      0.090533
# chi2        465484.062385     7.690727    27.241707     inf      0.303465
# exponpow    678726.275806   252.043881   271.594860     inf      0.532553
#
#              ks_pvalue
# cauchy    2.893321e-08
# lognorm   5.996555e-37
# norm      4.194767e-36
# chi2      0.000000e+00
# exponpow  0.000000e+00

# %% [markdown]
# 7. Para el data frame, seleccionemos solo los datos del 2023.

# %%
df1.index = pd.to_datetime(df1.index)

df_2023 = df1[df1.index.year == 2023]

# %%
df_2023.head()
# Out:
#                        Close  DiffPrice
# time
# 2023-01-02 00:00:00  1.06796   -0.00200
# 2023-01-02 01:00:00  1.06965    0.00169
# 2023-01-02 02:00:00  1.07058    0.00093
# 2023-01-02 03:00:00  1.06896   -0.00162
# 2023-01-02 04:00:00  1.06880   -0.00016

# %% [markdown]
# 8. El comando groupby permite agrupar los datos con la periodicidad deseada: 1 dias, 2 dias, 1 mes etc. Determina el promedio con una periodicidad de 15 dias, con periodidicidad de 1 semana, y una periodicidad de 1 mes
#
# ```python
#   df.groupby(pd.Grouper(key='time', freq='15D')).mean()
# ```

# %%
#15 dias
df_2023.groupby(pd.Grouper(freq='15D')).mean()
# Out:
#                Close  DiffPrice
# time
# 2023-01-02  1.069361   0.000047
# 2023-01-17  1.085565   0.000015
# 2023-02-01  1.077679  -0.000066
# 2023-02-16  1.063150  -0.000034
# 2023-03-03  1.063186   0.000026
# 2023-03-18  1.080936   0.000074
# 2023-04-02  1.093090   0.000063
# 2023-04-17  1.099084  -0.000006
# 2023-05-02  1.098889  -0.000059

# %%
#1 semana
df_2023.groupby(pd.Grouper(freq='1W')).mean()
# Out:
#                Close  DiffPrice
# time
# 2023-01-08  1.059972  -0.000047
# 2023-01-15  1.076002   0.000156
# 2023-01-22  1.082041   0.000020
# 2023-01-29  1.088414   0.000010
# 2023-02-05  1.089281  -0.000062
# 2023-02-12  1.073363  -0.000097
# 2023-02-19  1.069648   0.000014
# 2023-02-26  1.063374  -0.000124
# 2023-03-05  1.060854   0.000073
# 2023-03-12  1.060234   0.000004
# 2023-03-19  1.066518   0.000022
# 2023-03-26  1.077974   0.000079
# 2023-04-02  1.083874   0.000070
# 2023-04-09  1.090534   0.000047
# 2023-04-16  1.095646   0.000080
# 2023-04-23  1.096117  -0.000004
# 2023-04-30  1.101908   0.000023
# 2023-05-07  1.101674   0.000002
# 2023-05-14  1.096285  -0.000140

# %%
#1 mes
df_2023.groupby(pd.Grouper(freq='1ME')).mean()
# Out:
#                Close  DiffPrice
# time
# 2023-01-31  1.077463   0.000031
# 2023-02-28  1.071167  -0.000060
# 2023-03-31  1.070874   0.000049
# 2023-04-30  1.096051   0.000036
# 2023-05-31  1.098980  -0.000069

# %% [markdown]
# 9. Para los datos asociados a los meses de 2023, construya un histograma para cada mes.  Para ello puedo emplear el metodo groupby. Notetese que si no  realiza una operación después de aplicar el metodo grouby, podrias iterar sobre dicho objeto, por ejemplo:
#
# ```python
# q=df.groupby(pd.Grouper(key='time', freq='15D'))
#
# for name, group in q:
#   print(name, group)

# %%
df_months = df_2023.groupby(pd.Grouper(freq='1ME'))

for name, group in df_months:
  plt.hist(group['DiffPrice'], bins=50, label=name.strftime('%Y-%m'))
  plt.xlabel('DiffPrice')
  plt.ylabel('Frequency')
  plt.legend()
  plt.title('Histogram of DiffPrice')
  plt.grid()

# %% [markdown]
# ## Análisis de datos con pandas.
#
# Para el siguiente [dataset](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29) realizar lo siguiente:

# %% [markdown]
# 1. Leer los datos desde una página web.

# %%
# !pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

# data (as pandas dataframes)
X = breast_cancer_wisconsin_diagnostic.data.features
y = breast_cancer_wisconsin_diagnostic.data.targets

# %% [markdown]
# 2. Renombrar las columnas en formato PascalCase.

# %%
X.columns = [x.title().replace("_","") for x in X.columns]

# %% [markdown]
# 3. Utilizar los métodos `head()`, `tail()`, `describe()` e `info()` para obtener información sobre el `DataFrame`.

# %%
X.head()
# Out:
#    Radius1  Texture1  Perimeter1   Area1  Smoothness1  Compactness1  \
# 0    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#    Concavity1  ConcavePoints1  Symmetry1  FractalDimension1  ...  Radius3  \
# 0      0.3001         0.14710     0.2419            0.07871  ...    25.38
# 1      0.0869         0.07017     0.1812            0.05667  ...    24.99
# 2      0.1974         0.12790     0.2069            0.05999  ...    23.57
# 3      0.2414         0.10520     0.2597            0.09744  ...    14.91
# 4      0.1980         0.10430     0.1809            0.05883  ...    22.54
#
#    Texture3  Perimeter3   Area3  Smoothness3  Compactness3  Concavity3  \
# 0     17.33      184.60  2019.0       0.1622        0.6656      0.7119
# 1     23.41      158.80  1956.0       0.1238        0.1866      0.2416
# 2     25.53      152.50  1709.0       0.1444        0.4245      0.4504
# 3     26.50       98.87   567.7       0.2098        0.8663      0.6869
# 4     16.67      152.20  1575.0       0.1374        0.2050      0.4000
#
#    ConcavePoints3  Symmetry3  FractalDimension3
# 0          0.2654     0.4601            0.11890
# 1          0.1860     0.2750            0.08902
# 2          0.2430     0.3613            0.08758
# 3          0.2575     0.6638            0.17300
# 4          0.1625     0.2364            0.07678
#
# [5 rows x 30 columns]

# %%
X.tail()
# Out:
#      Radius1  Texture1  Perimeter1   Area1  Smoothness1  Compactness1  \
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      Concavity1  ConcavePoints1  Symmetry1  FractalDimension1  ...  Radius3  \
# 564     0.24390         0.13890     0.1726            0.05623  ...   25.450
# 565     0.14400         0.09791     0.1752            0.05533  ...   23.690
# 566     0.09251         0.05302     0.1590            0.05648  ...   18.980
# 567     0.35140         0.15200     0.2397            0.07016  ...   25.740
# 568     0.00000         0.00000     0.1587            0.05884  ...    9.456
#
#      Texture3  Perimeter3   Area3  Smoothness3  Compactness3  Concavity3  \
# 564     26.40      166.10  2027.0      0.14100       0.21130      0.4107
# 565     38.25      155.00  1731.0      0.11660       0.19220      0.3215
# 566     34.12      126.70  1124.0      0.11390       0.30940      0.3403
# 567     39.42      184.60  1821.0      0.16500       0.86810      0.9387
# 568     30.37       59.16   268.6      0.08996       0.06444      0.0000
#
#      ConcavePoints3  Symmetry3  FractalDimension3
# 564          0.2216     0.2060            0.07115
# 565          0.1628     0.2572            0.06637
# 566          0.1418     0.2218            0.07820
# 567          0.2650     0.4087            0.12400
# 568          0.0000     0.2871            0.07039
#
# [5 rows x 30 columns]

# %%
X.describe()
# Out:
#           Radius1    Texture1  Perimeter1        Area1  Smoothness1  \
# count  569.000000  569.000000  569.000000   569.000000   569.000000
# mean    14.127292   19.289649   91.969033   654.889104     0.096360
# std      3.524049    4.301036   24.298981   351.914129     0.014064
# min      6.981000    9.710000   43.790000   143.500000     0.052630
# 25%     11.700000   16.170000   75.170000   420.300000     0.086370
# 50%     13.370000   18.840000   86.240000   551.100000     0.095870
# 75%     15.780000   21.800000  104.100000   782.700000     0.105300
# max     28.110000   39.280000  188.500000  2501.000000     0.163400
#
#        Compactness1  Concavity1  ConcavePoints1   Symmetry1  \
# count    569.000000  569.000000      569.000000  569.000000
# mean       0.104341    0.088799        0.048919    0.181162
# std        0.052813    0.079720        0.038803    0.027414
# min        0.019380    0.000000        0.000000    0.106000
# 25%        0.064920    0.029560        0.020310    0.161900
# 50%        0.092630    0.061540        0.033500    0.179200
# 75%        0.130400    0.130700        0.074000    0.195700
# max        0.345400    0.426800        0.201200    0.304000
#
#        FractalDimension1  ...     Radius3    Texture3  Perimeter3  \
# count         569.000000  ...  569.000000  569.000000  569.000000
# mean            0.062798  ...   16.269190   25.677223  107.261213
# std             0.007060  ...    4.833242    6.146258   33.602542
# min             0.049960  ...    7.930000   12.020000   50.410000
# 25%             0.057700  ...   13.010000   21.080000   84.110000
# 50%             0.061540  ...   14.970000   25.410000   97.660000
# 75%             0.066120  ...   18.790000   29.720000  125.400000
# max             0.097440  ...   36.040000   49.540000  251.200000
#
#              Area3  Smoothness3  Compactness3  Concavity3  ConcavePoints3  \
# count   569.000000   569.000000    569.000000  569.000000      569.000000
# mean    880.583128     0.132369      0.254265    0.272188        0.114606
# std     569.356993     0.022832      0.157336    0.208624        0.065732
# min     185.200000     0.071170      0.027290    0.000000        0.000000
# 25%     515.300000     0.116600      0.147200    0.114500        0.064930
# 50%     686.500000     0.131300      0.211900    0.226700        0.099930
# 75%    1084.000000     0.146000      0.339100    0.382900        0.161400
# max    4254.000000     0.222600      1.058000    1.252000        0.291000
#
#         Symmetry3  FractalDimension3
# count  569.000000         569.000000
# mean     0.290076           0.083946
# std      0.061867           0.018061
# min      0.156500           0.055040
# 25%      0.250400           0.071460
# 50%      0.282200           0.080040
# 75%      0.317900           0.092080
# max      0.663800           0.207500
#
# [8 rows x 30 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Radius1            569 non-null    float64
#  1   Texture1           569 non-null    float64
#  2   Perimeter1         569 non-null    float64
#  3   Area1              569 non-null    float64
#  4   Smoothness1        569 non-null    float64
#  5   Compactness1       569 non-null    float64
#  6   Concavity1         569 non-null    float64
#  7   ConcavePoints1     569 non-null    float64
#  8   Symmetry1          569 non-null    float64
#  9   FractalDimension1  569 non-null    float64
#  10  Radius2            569 non-null    float64
#  11  Texture2           569 non-null    float64
#  12  Perimeter2         569 non-null    float64
#  13  Area2              569 non-null    float64
#  14  Smoothness2        569 non-null    float64
#  15  Compactness2       569 non-null    float64
#  16  Concavity2         569 non-null    float64
#  17  ConcavePoints2     569 non-null    float64
#  18  Symmetry2          569 non-null    float64
#  19  FractalDimension2  569 non-null    float64
#  20  Radius3            569 non-null    float64
#  21  Texture3           569 non-null    float64
#  22  Perimeter3         569 non-null    float64
#  23  Area3              569 non-null    float64
#  24  Smoothness3        569 non-null    float64
#  25  Compactness3       569 non-null    float64
#  26  Concavity3         569 non-null    float64
#  27  ConcavePoints3     569 non-null    float64
#  28  Symmetry3          569 non-null    float64
#  29  FractalDimension3  569 non-null    float64
# dtypes: float64(30)
# memory usage: 133.5 KB

# %% [markdown]
# 4. Contabilizar la cantidad de valores nulos (`null` o `NaN`) en el `DataFrame`.
#    Si se encuentran valores nulos, ¿qué estrategia propondrías para reemplazarlos?

# %%
print(f"La cantidad de valores nan en X es: {X.isna().sum().sum()}")
print(f"La cantidad de valores null en X es: {X.isnull().sum().sum()}")
print(f"La cantidad de valores nan en y es: {y.isna().sum().sum()}")
print(f"La cantidad de valores null en y es: {y.isnull().sum().sum()}")
# Out:
# La cantidad de valores nan en X es: 0
# La cantidad de valores null en X es: 0
# La cantidad de valores nan en y es: 0
# La cantidad de valores null en y es: 0

# %% [markdown]
# 5. Identificar los valores únicos en la columna `target` que representan las etiquetas B y M (Benigno y Maligno, respectivamente).
#    Utiliza el método `unique()` para mostrar estos valores.

# %%
y.Diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# 6. Realizar un conteo de los casos etiquetados como B y M utilizando la librería `seaborn` y el método `countplot()`:
#
# ```python
# import seaborn as sns
# sns.countplot?
# ```

# %%
import seaborn as sns
sns.countplot(y.Diagnosis,color='orangered')
plt.ylabel('Diagnosis')
plt.xlabel('Count')
plt.title('Count of Diagnosis')
plt.show()

# %% [markdown]
# 7. Agregar una nueva columna llamada `DiagnosisNumeric` donde se asigna el valor 0 a la etiqueta B (Benigno) y el valor 1 a la etiqueta M (Maligno).

# %%
y=y.copy()
y["DiagnosisNumeric"] = (y["Diagnosis"] == "M")*1 #boolean * 1 = 0 si boolean=False 1 si boolean=True

# %%
y.head()
# Out:
#   Diagnosis  DiagnosisNumeric
# 0         M                 1
# 1         M                 1
# 2         M                 1
# 3         M                 1
# 4         M                 1

# %% [markdown]
# 8. Normalizar cada columna respecto a su media y desviación estándar utilizando la fórmula:
#    `(x - mean(x)) / std(x)`

# %%
X_norm = (X - X.mean()) / X.std()
X_norm
# Out:
#       Radius1  Texture1  Perimeter1     Area1  Smoothness1  Compactness1  \
# 0    1.096100 -2.071512    1.268817  0.983510     1.567087      3.280628
# 1    1.828212 -0.353322    1.684473  1.907030    -0.826235     -0.486643
# 2    1.578499  0.455786    1.565126  1.557513     0.941382      1.052000
# 3   -0.768233  0.253509   -0.592166 -0.763792     3.280667      3.399917
# 4    1.748758 -1.150804    1.775011  1.824624     0.280125      0.538866
# ..        ...       ...         ...       ...          ...           ...
# 564  2.109139  0.720838    2.058974  2.341795     1.040926      0.218868
# 565  1.703356  2.083301    1.614511  1.722326     0.102368     -0.017817
# 566  0.701667  2.043775    0.672084  0.577445    -0.839745     -0.038646
# 567  1.836725  2.334403    1.980781  1.733693     1.524426      3.269267
# 568 -1.806811  1.220718   -1.812793 -1.346604    -3.109349     -1.149741
#
#      Concavity1  ConcavePoints1  Symmetry1  FractalDimension1  ...   Radius3  \
# 0      2.650542        2.530249   2.215566           2.253764  ...  1.885031
# 1     -0.023825        0.547662   0.001391          -0.867889  ...  1.804340
# 2      1.362280        2.035440   0.938859          -0.397658  ...  1.510541
# 3      1.914213        1.450431   2.864862           4.906602  ... -0.281217
# 4      1.369806        1.427237  -0.009552          -0.561956  ...  1.297434
# ..          ...             ...        ...                ...  ...       ...
# 564    1.945573        2.318924  -0.312314          -0.930209  ...  1.899514
# 565    0.692434        1.262558  -0.217473          -1.057681  ...  1.535369
# 566    0.046547        0.105684  -0.808406          -0.894800  ...  0.560868
# 567    3.294046        2.656528   2.135315           1.042778  ...  1.959515
# 568   -1.113893       -1.260710  -0.819349          -0.560539  ... -1.409652
#
#      Texture3  Perimeter3     Area3  Smoothness3  Compactness3  Concavity3  \
# 0   -1.358098    2.301575  1.999478     1.306537      2.614365    2.107672
# 1   -0.368879    1.533776  1.888827    -0.375282     -0.430066   -0.146620
# 2   -0.023953    1.346291  1.455004     0.526944      1.081980    0.854222
# 3    0.133866   -0.249720 -0.549538     3.391291      3.889975    1.987839
# 4   -1.465481    1.337363  1.219651     0.220362     -0.313119    0.612640
# ..        ...         ...       ...          ...           ...         ...
# 564  0.117596    1.751022  2.013529     0.378033     -0.273077    0.663928
# 565  2.045599    1.420690  1.493644    -0.690623     -0.394473    0.236365
# 566  1.373645    0.578492  0.427529    -0.808876      0.350427    0.326479
# 567  2.235958    2.301575  1.651717     1.429169      3.901415    3.194794
# 568  0.763518   -1.431475 -1.074867    -1.857384     -1.206491   -1.304683
#
#      ConcavePoints3  Symmetry3  FractalDimension3
# 0          2.294058   2.748204           1.935312
# 1          1.086129  -0.243675           0.280943
# 2          1.953282   1.151242           0.201214
# 3          2.173873   6.040726           4.930672
# 4          0.728618  -0.867590          -0.396751
# ..              ...        ...                ...
# 564        1.627719  -1.358963          -0.708467
# 565        0.733182  -0.531387          -0.973122
# 566        0.413705  -1.103578          -0.318129
# 567        2.287972   1.917396           2.217684
# 568       -1.743529  -0.048096          -0.750546
#
# [569 rows x 30 columns]

# %% [markdown]
# 9. Agrupar características similares y calcular su promedio.
#    Para las siguientes características:
#
# ```python
# ['RadiusMean', 'TextureMean', 'PerimeterMean', 'AreaMean', 'SmoothnessMean', 'CompactnessMean', 'ConcavityMean', 'ConcavePointsMean', "SymmetryMean", "FractalDimensionMean"]
# ```
#
# Usa expresiones regulares para identificar patrones comunes, como `radius1`, `radius2`,`radius3`, etc., y calcular los promedios. Por ejemplo:
#
# ```python
# re.match(r'^[a-zA-Z_]+', "holamundo12341").group(0)
# ```
#
# También puedes utilizar el método `startswith()` para buscar estos patrones en los nombres de las columnas.

# %%
import regex as re

# %%
caracteristicas = ['RadiusMean', 'TextureMean', 'PerimeterMean', 'AreaMean',
                   'SmoothnessMean', 'CompactnessMean', 'ConcavityMean',
                   'ConcavePointsMean', "SymmetryMean", "FractalDimensionMean"]

# %%
grupos = {}
for col in X_norm.columns:
    base = re.match(r'^[a-zA-Z]+', col).group(0)
    if base not in grupos:
      grupos[base] = []
    grupos[base].append(col)

#dataframe de la longitud de index
X_promedios = pd.DataFrame(index = X_norm.index)

for base, columnas in grupos.items():
    print(base, columnas)
    X_promedios[f'{base}Mean'] = X_norm[columnas].mean(axis=1)
# Out:
# Radius ['Radius1', 'Radius2', 'Radius3']
# Texture ['Texture1', 'Texture2', 'Texture3']
# Perimeter ['Perimeter1', 'Perimeter2', 'Perimeter3']
# Area ['Area1', 'Area2', 'Area3']
# Smoothness ['Smoothness1', 'Smoothness2', 'Smoothness3']
# Compactness ['Compactness1', 'Compactness2', 'Compactness3']
# Concavity ['Concavity1', 'Concavity2', 'Concavity3']
# ConcavePoints ['ConcavePoints1', 'ConcavePoints2', 'ConcavePoints3']
# Symmetry ['Symmetry1', 'Symmetry2', 'Symmetry3']
# FractalDimension ['FractalDimension1', 'FractalDimension2', 'FractalDimension3']

# %%
X_promedios["DiagnosisNumeric"] = y["DiagnosisNumeric"]
X_promedios.head()
# Out:
#    RadiusMean  TextureMean  PerimeterMean  AreaMean  SmoothnessMean  \
# 0    1.822892    -1.331460       2.133644  1.822793        0.886604
# 1    1.377122    -0.532558       1.160448  1.512536       -0.602112
# 2    1.438879    -0.115855       1.253866  1.397605        0.390527
# 3   -0.241121     0.092354      -0.185181 -0.533818        2.453684
# 4    1.438539    -1.135278       1.461481  1.411195        0.660750
#
#    CompactnessMean  ConcavityMean  ConcavePointsMean  SymmetryMean  \
# 0         2.403566       1.827201           1.828182      2.037172
# 1        -0.536342      -0.203612           0.631241     -0.349009
# 2         0.982746       0.809797           1.804099      0.775643
# 3         3.343920       1.573617           1.579444      4.544703
# 4         0.059090       0.936729           1.099685     -0.412639
#
#    FractalDimensionMean  DiagnosisNumeric
# 0              1.698454                 1
# 1             -0.228767                 1
# 2              0.032286                 1
# 3              3.960995                 1
# 4             -0.153272                 1

# %% [markdown]
# 10. Crear un gráfico donde se muestre el histograma de la columna `RadiusMean` separado por las etiquetas B y M, utilizando colores diferentes (naranja y azul, respectivamente) para cada diagnóstico.

# %%
M = X_promedios[X_promedios["DiagnosisNumeric"] == 1]
B = X_promedios[X_promedios["DiagnosisNumeric"] == 0]

fig = plt.figure(figsize=(8,5))
plt.hist(B['RadiusMean'], bins=40, alpha=0.7, label='B',color='orange')
plt.hist(M['RadiusMean'], bins=40, alpha=0.7, label='M',color='blue')
plt.xlabel('RadiusMean')
plt.ylabel('Frequency')
plt.title('Histogram of RadiusMean')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 11. Generar gráficos de violín para múltiples características.
#    Para las columnas:
#
#    - `RadiusMean`
#    - `TextureMean`
#    - `PerimeterMean`
#    - `AreaMean`
#    - `SmoothnessMean`
#    - `CompactnessMean`
#    - `ConcavityMean`
#    - `ConcavePointsMean`
#    - `Symmetry3`
#    - `FractalDimension3`
#
#    Realiza un gráfico múltiple tipo violín, como en el siguiente ejemplo:
#
# ```python
# data = pd.melt(df.iloc[:, 0:10], id_vars="Diagnosis", var_name="features", value_name="value")
# sns.violinplot(x="features", y="value", hue="Diagnosis", data=data, split=True, inner="quart")
# plt.xticks(rotation=45)
# ```

# %%
X_promedios.columns
# Out:
# Index(['RadiusMean', 'TextureMean', 'PerimeterMean', 'AreaMean',
#        'SmoothnessMean', 'CompactnessMean', 'ConcavityMean',
#        'ConcavePointsMean', 'SymmetryMean', 'FractalDimensionMean',
#        'DiagnosisNumeric'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(10,6))
data = pd.melt(X_promedios.iloc[:, 0:11], id_vars="DiagnosisNumeric", var_name="features", value_name="value")
sns.violinplot(x="features", y="value", hue="DiagnosisNumeric", data=data, split=True, inner="quart",palette={1:'blue',0:'orange'})
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 12.  Determinar y eliminar los valores atípicos (`outliers`) en la columna `RadiusMean`.
#
# Para identificarlos, construye un gráfico tipo `boxplot`:
#
# ```python
# df.boxplot(column="RadiusMean", by='Diagnosis', sym='k.', figsize=(18,6))
# ```
#
# Usa el rango intercuartílico (IQR) para definir los outliers. Los valores fuera del rango [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR] se consideran outliers. Ejemplo de cómo eliminar estos valores:
#
# ```python
# Q1 = df['edad'].quantile(0.25)
# Q3 = df['edad'].quantile(0.75)
# IQR = Q3 - Q1
# df = df[~((df['edad'] < (Q1 - 1.5 * IQR)) | (df['edad'] > (Q3 + 1.5 * IQR)))]
# ```
#
# Otra alternativa es utilizar el puntaje Z para detectar `outliers`:
#
# ```python
# df = df[(np.abs(stats.zscore(df['edad'])) < 3)]
# ```

# %%
X_promedios.boxplot(column="RadiusMean", by='DiagnosisNumeric', sym='k.', figsize=(18,6))
plt.show()

# %%
Q1 = X_promedios['RadiusMean'].quantile(0.25)
Q3 = X_promedios['RadiusMean'].quantile(0.75)
IQR = Q3 - Q1
X_promedios = X_promedios[~((X_promedios['RadiusMean'] < (Q1 - 1.5 * IQR)) | (X_promedios['RadiusMean'] > (Q3 + 1.5 * IQR)))]

# %%
X_promedios.boxplot(column="RadiusMean", by='DiagnosisNumeric', sym='k.', figsize=(10,6))
plt.show()

# %% [markdown]
# 13. Encontrar la matrix de correlación, emplear el metodo corr(), dentro de seaborn buscar el metodo heatmap() para realizar un grafico de la matrix de correlación.

# %%
corr = X_promedios.corr()
#que esten redondeados los numeros en la grafica
fig = plt.figure(figsize=(10,10))

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# 14. ¿Que otro tipo de gráficos pueden ser realizados para entender mejor los datos?

# %%
sns.pairplot(
    X_promedios[["DiagnosisNumeric", "RadiusMean", "PerimeterMean", "AreaMean", "ConcavePointsMean","ConcavityMean"]],
    hue="DiagnosisNumeric",
    corner=True,  # opcional: para evitar duplicados en la matriz
    height=1.4,  # altura de cada gráfico
    palette={1:'blue',0:'orange'},
    plot_kws={"alpha": 0.6}  # opcional: para hacer los puntos semitransparentes
)
plt.show()

# %%
sns.barplot(data=data, x="features", y="value", hue="DiagnosisNumeric", palette={1:'blue',0:'orange'}, errorbar="sd")
plt.xticks(rotation=90)
plt.title("Barplot of Features by Diagnosis")
plt.show()
