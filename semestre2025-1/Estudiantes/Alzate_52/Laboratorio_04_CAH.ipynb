# %% [markdown]
# <a href="https://colab.research.google.com/github/CienciaDatosUdea/002_EstudiantesAprendizajeEstadistico/blob/main/semestre2024-2/Sesiones/Sesion_05_regresion_multivariadaV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio 04
# Objetivo: Programar una regresión multivariada
#
#
# 1. Para simular un conjunto de características $x_1$ , $x_2$,..., $x_n$ trabajaremos en la primera parte con dos características de datos aleatorios que presentan un plano y mostraremos que los párametros optimizados se corresponden con el valor esperado.
#
# - Definir la ecuación  $y = 2.1*x_1 - 3.1*x_2$, y generar números aleatorios que pertenecen al plano.
#
# - Realizar un diagrama 3D de los puntos generados aleatoriamente.
#
#
# Nuestro objetivo será encontrar los valores $\theta_0 = 0, \theta_1=2.1, \theta_1=3.1$ que mejor ajustar el plano, empleando cálculos vectorizados.
#
# 2. Inicializar conjunto de parámetros $\Theta$ de manera aleatoria.
# 3. Construir la matrix X con dimensiones $(n+1, m)$, m es el numero de datos de entrenamiento y (n) el número de caracteristicas.
# 4. Calcular la función de coste(revise cuidosamente las dimensiones de cada matriz):
#
#   - $h = \Theta^{T} X $
#   - $\Lambda= (h -Y) $
#   - $\Lambda*= (h -Y)^2 $
#   - $\Lambda= [\Lambda_1,\Lambda_2, ...,\Lambda_m]$
#   - $J = \frac{1}{2m} \sum_{i}^m \Lambda_i $
#
# 5. Aplicar el gradiente descendente:
#   - Encontrar el gradiente.
#     $\nabla J = \Lambda X.T$
#
#   - Actualizar los nuevos parametros:
#     $\Theta_{n+1}=\Theta_{n}-\alpha\nabla J$
#
#
# 6. Iterar para encontrar los valores $\Theta$ que se ajustan el plano.

# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# #1.
# Definición de los puntos, ecuación de la recta y gráfica en 3D

# %%
#Definición de los puntos
N = 100
x1 = np.linspace(-1, 1, N)
x2 = np.linspace(-1, 1, N)
X_1, X_2 = np.meshgrid(x1, x2)

#Ecuación recta
Y = 0.2 * X_1 - 0.5 * X_2

#Gráfica
fig = go.Figure(go.Surface(x=X_1, y=X_2, z=Y))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="83676de0-cb67-4ed9-8a12-21c4b6a27d6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83676de0-cb67-4ed9-8a12-21c4b6a27d6d")) {                    Plotly.newPlot(                        "83676de0-cb67-4ed9-8a12-21c4b6a27d6d",                        [{"x":[[-1.0,-0.9797979797979798,-0.9595959595959596,-0.9393939393939394,-0.9191919191919192,-0.898989898989899,-0.8787878787878788,-0.8585858585858586,-0.8383838383838383,-0.8181818181818181,-0.797979797979798,-0.7777777777777778,-0.7575757575757576,-0.7373737373737373,-0.7171717171717171,-0.696969696969697,-0.6767676767676767,-0.6565656565656566,-0.6363636363636364,-0.6161616161616161,-0.5959595959595959,-0.5757575757575757,-0.5555555555555556,-0.5353535353535352,-0.5151515151515151,-0.4949494949494949,-0.4747474747474747,-0.4545454545454545,-0.43434343434343425,-0.41414141414141414,-0.3939393939393939,-0.3737373737373737,-0.3535353535353535,-0.33333333333333326,-0.31313131313131304,-0.2929292929292928,-0.2727272727272727,-0.2525252525252525,-0.23232323232323226,-0.21212121212121204,-0.19191919191919182,-0.1717171717171716,-0.1515151515151515,-0.13131313131313127,-0.11111111111111105,-0.09090909090909083,-0.07070707070707061,-0.050505050505050386,-0.030303030303030276,-0.010101010101010055,0.010101010101010166,0.030303030303030498,0.05050505050505061,0.07070707070707072,0.09090909090909105,0.11111111111111116,0.1313131313131315,0.1515151515151516,0.1717171717171717,0.19191919191919204,0.21212121212121215,0.2323232323232325,0.2525252525252526,0.27272727272727293,0.29292929292929304,0.31313131313131315,0.3333333333333335,0.3535353535353536,0.3737373737373739,0.39393939393939403,0.41414141414141437,0.4343434343434345,0.4545454545454546,0.4747474747474749,0.49494949494949503,0.5151515151515154,0.5353535353535355,0.5555555555555556,0.5757575757575759,0.595959595959596,0.6161616161616164,0.6363636363636365,0.6565656565656568,0.6767676767676769,0.696969696969697,0.7171717171717173,0.7373737373737375,0.7575757575757578,0.7777777777777779,0.7979797979797982,0.8181818181818183,0.8383838383838385,0.8585858585858588,0.8787878787878789,0.8989898989898992,0.9191919191919193,0.9393939393939394,0.9595959595959598,0.9797979797979799,1.0],[-1.0,-0.9797979797979798,-0.9595959595959596,-0.9393939393939394,-0.9191919191919192,-0.898989898989899,-0.8787878787878788,-0.8585858585858586,-0.8383838383838383,-0.8181818181818181,-0.797979797979798,-0.7777777777777778,-0.7575757575757576,-0.7373737373737373,-0.7171717171717171,-0.696969696969697,-0.6767676767676767,-0.6565656565656566,-0.6363636363636364,-0.6161616161616161,-0.5959595959595959,-0.5757575757575757,-0.5555555555555556,-0.5353535353535352,-0.5151515151515151,-0.4949494949494949,-0.4747474747474747,-0.4545454545454545,-0.43434343434343425,-0.41414141414141414,-0.3939393939393939,-0.3737373737373737,-0.3535353535353535,-0.33333333333333326,-0.31313131313131304,-0.2929292929292928,-0.2727272727272727,-0.2525252525252525,-0.23232323232323226,-0.21212121212121204,-0.19191919191919182,-0.1717171717171716,-0.1515151515151515,-0.13131313131313127,-0.11111111111111105,-0.09090909090909083,-0.07070707070707061,-0.050505050505050386,-0.030303030303030276,-0.010101010101010055,0.010101010101010166,0.030303030303030498,0.05050505050505061,0.07070707070707072,0.09090909090909105,0.11111111111111116,0.1313131313131315,0.1515151515151516,0.1717171717171717,0.19191919191919204,0.21212121212121215,0.2323232323232325,0.2525252525252526,0.27272727272727293,0.29292929292929304,0.31313131313131315,0.3333333333333335,0.3535353535353536,0.3737373737373739,0.39393939393939403,0.41414141414141437,0.4343434343434345,0.4545454545454546,0.4747474747474749,0.4949494 ...

# %%
#Puntos aleatorios y ecuación de la recta.

N=100
x_1= 2*np.random.random(N)-1
x_2= 2*np.random.random(N)-1
y_label = 0.2 * x_1 - 0.5 * x_2 #+ 0.2*(2*np.random.random(N)-1)

# %%
#Gráfica
fig = go.Figure(go.Surface(x=X_1, y=X_2, z=Y))
fig.add_trace(go.Scatter3d(x=x_1, y=x_2, z=y_label, mode='markers', marker=dict(size=4, color='white')))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="871e0610-cb96-4824-8493-d751f8b76d0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("871e0610-cb96-4824-8493-d751f8b76d0a")) {                    Plotly.newPlot(                        "871e0610-cb96-4824-8493-d751f8b76d0a",                        [{"x":[[-1.0,-0.9797979797979798,-0.9595959595959596,-0.9393939393939394,-0.9191919191919192,-0.898989898989899,-0.8787878787878788,-0.8585858585858586,-0.8383838383838383,-0.8181818181818181,-0.797979797979798,-0.7777777777777778,-0.7575757575757576,-0.7373737373737373,-0.7171717171717171,-0.696969696969697,-0.6767676767676767,-0.6565656565656566,-0.6363636363636364,-0.6161616161616161,-0.5959595959595959,-0.5757575757575757,-0.5555555555555556,-0.5353535353535352,-0.5151515151515151,-0.4949494949494949,-0.4747474747474747,-0.4545454545454545,-0.43434343434343425,-0.41414141414141414,-0.3939393939393939,-0.3737373737373737,-0.3535353535353535,-0.33333333333333326,-0.31313131313131304,-0.2929292929292928,-0.2727272727272727,-0.2525252525252525,-0.23232323232323226,-0.21212121212121204,-0.19191919191919182,-0.1717171717171716,-0.1515151515151515,-0.13131313131313127,-0.11111111111111105,-0.09090909090909083,-0.07070707070707061,-0.050505050505050386,-0.030303030303030276,-0.010101010101010055,0.010101010101010166,0.030303030303030498,0.05050505050505061,0.07070707070707072,0.09090909090909105,0.11111111111111116,0.1313131313131315,0.1515151515151516,0.1717171717171717,0.19191919191919204,0.21212121212121215,0.2323232323232325,0.2525252525252526,0.27272727272727293,0.29292929292929304,0.31313131313131315,0.3333333333333335,0.3535353535353536,0.3737373737373739,0.39393939393939403,0.41414141414141437,0.4343434343434345,0.4545454545454546,0.4747474747474749,0.49494949494949503,0.5151515151515154,0.5353535353535355,0.5555555555555556,0.5757575757575759,0.595959595959596,0.6161616161616164,0.6363636363636365,0.6565656565656568,0.6767676767676769,0.696969696969697,0.7171717171717173,0.7373737373737375,0.7575757575757578,0.7777777777777779,0.7979797979797982,0.8181818181818183,0.8383838383838385,0.8585858585858588,0.8787878787878789,0.8989898989898992,0.9191919191919193,0.9393939393939394,0.9595959595959598,0.9797979797979799,1.0],[-1.0,-0.9797979797979798,-0.9595959595959596,-0.9393939393939394,-0.9191919191919192,-0.898989898989899,-0.8787878787878788,-0.8585858585858586,-0.8383838383838383,-0.8181818181818181,-0.797979797979798,-0.7777777777777778,-0.7575757575757576,-0.7373737373737373,-0.7171717171717171,-0.696969696969697,-0.6767676767676767,-0.6565656565656566,-0.6363636363636364,-0.6161616161616161,-0.5959595959595959,-0.5757575757575757,-0.5555555555555556,-0.5353535353535352,-0.5151515151515151,-0.4949494949494949,-0.4747474747474747,-0.4545454545454545,-0.43434343434343425,-0.41414141414141414,-0.3939393939393939,-0.3737373737373737,-0.3535353535353535,-0.33333333333333326,-0.31313131313131304,-0.2929292929292928,-0.2727272727272727,-0.2525252525252525,-0.23232323232323226,-0.21212121212121204,-0.19191919191919182,-0.1717171717171716,-0.1515151515151515,-0.13131313131313127,-0.11111111111111105,-0.09090909090909083,-0.07070707070707061,-0.050505050505050386,-0.030303030303030276,-0.010101010101010055,0.010101010101010166,0.030303030303030498,0.05050505050505061,0.07070707070707072,0.09090909090909105,0.11111111111111116,0.1313131313131315,0.1515151515151516,0.1717171717171717,0.19191919191919204,0.21212121212121215,0.2323232323232325,0.2525252525252526,0.27272727272727293,0.29292929292929304,0.31313131313131315,0.3333333333333335,0.3535353535353536,0.3737373737373739,0.39393939393939403,0.41414141414141437,0.4343434343434345,0.4545454545454546,0.4747474747474749,0.4949494 ...

# %% [markdown]
# #2 y 3
#
# 2. Inicializar conjunto de parámetros $\Theta$ de manera aleatoria.
# 3. Construir la matrix X con dimensiones $(n+1, m)$, m es el numero de datos de entrenamiento y (n) el número de caracteristicas.

# %%
N = 100
x_1 = 2 * np.random.random(N) - 1
x_2 = 2 * np.random.random(N) - 1

y_label = 0.2 * x_1 - 0.5 * x_2 #+ 0.2*(2*np.random.random(N)-1)
df = pd.DataFrame({"x1":x_1, "x2":x_2, "y":y_label})
df["ones"]=1

# %%
X = df[["ones", "x1", "x2"]].values.T
Y = df.y.values.reshape(1, N)

# %%
Nfeatures = np.shape(X)[0]
m = np.shape(X)[1]
print(Nfeatures, m)
# Out:
# 3 100

# %% [markdown]
# #4. y 5.
#
# Función de coste para valores aleatorios de theta y gradiente descendente

# %%
def model(theta, X):
  return theta.T@X

def costo(h, Y):
  J= (h-Y)**2
  return J.mean()

def update_params(theta, h, Y, learning_rate):
  """
  Gradiente descendente
  """
  grad = np.dot((h-Y), X.T).T
  theta = theta - learning_rate*grad
  return theta

# %%
theta=np.random.random(3).reshape(3, 1)
learning_rate=0.01
Niter=100
J = np.zeros(Niter)

for i in range(0, Niter):
  h = model(theta, X)
  J[i] = costo(h, Y)
  theta = update_params(theta, h, Y, learning_rate)

# %%
plt.plot(J)
plt.title('Función de Coste')
plt.grid()

# %% [markdown]
# Hint de la clase: implementar esto en una clase para mayor eficiencia.

# %%
import numpy as np

class MultilinearRegresion():
    def __init__(self, X, Y):
        self.X = X  # X debe tener forma (n_features, m)
        self.Y = Y  # Y debe tener forma (1, m)
        self.Nfeatures = X.shape[0]
        self.m = X.shape[1]
        self.theta = np.random.random(self.Nfeatures).reshape(self.Nfeatures, 1)
        self.J_history = []

    def model(self):
        self.h = self.theta.T @ self.X  # (1, m)

    def costo(self):
        J = ((self.h - self.Y) ** 2).mean()
        self.J_history.append(J)
        self.J = J

    def update_params(self, learning_rate):
        """
        Gradiente descendente
        """
        grad = np.dot((self.h - self.Y), self.X.T).T / self.m  # (n_features, 1)
        self.theta -= learning_rate * grad

    def fit(self, learning_rate, Niter=100):
        for i in range(Niter):
            self.model()
            self.costo()
            self.update_params(learning_rate)
        return self.theta

    def predict(self, X_new):
        return self.theta.T @ X_new

# %% [markdown]
# Evaluación de la clase.

# %%
lr = MultilinearRegresion(X, Y)

# %%
lr.fit(0.01)
# Out:
# array([[ 0.03788666],
#        [ 0.31633867],
#        [-0.13666216]])

# %%
lr.theta
# Out:
# array([[ 0.03788666],
#        [ 0.31633867],
#        [-0.13666216]])

# %% [markdown]
# #6.
# Iterar para encontrar los valores $\Theta$ que se ajustan el plano.

# %%
modelo = MultilinearRegresion(X, Y)
theta_entrenado = modelo.fit(learning_rate=0.01, Niter=1000)

print("Valores ajustados de θ:")
for i, t in enumerate(theta_entrenado.flatten()):
    print(f"θ{i} = {t:.4f}")
# Out:
# Valores ajustados de θ:
# θ0 = 0.0059
# θ1 = 0.1932
# θ2 = -0.4559

# %% [markdown]
# Como vemos, a medida que itero, los valores se vuelven bastante aproximados en el sentido de que el resultado debería ser algo como [ intercepto, $0.2  x_1$, $-0.5 x_2$ ]
# Y vemos que $\theta_1 = 0.19$ lo cual es aproximadamente 0.2 como debería dar según la ecuación y $\theta_2 = -0.45$ que también es aproximadamente -0.5 que es su valor en la ecuación.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_1, x_2, y_label, c='blue', label='Datos reales')

# Plano ajustado
x_surf, y_surf = np.meshgrid(np.linspace(-1, 1, 10), np.linspace(-1, 1, 10))
z_surf = (theta_entrenado[0] + theta_entrenado[1]*x_surf + theta_entrenado[2]*y_surf)

ax.plot_surface(x_surf, y_surf, z_surf, alpha=0.5, color='red', label='Plano ajustado')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
plt.title("Ajuste de plano a los datos")
plt.show()

# %%
#Gráfica de la función de coste
plt.plot(modelo.J_history)
plt.grid()
plt.xlabel("Iteración")
plt.ylabel("Costo (MSE)")
plt.title("Convergencia de la función de coste")
plt.show()

# %% [markdown]
# El error se reduce a medida que se aumentan las iteraciones para obtener los mejores parámetros.
