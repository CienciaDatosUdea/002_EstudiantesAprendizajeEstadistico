# %% [markdown]
# <a href="https://colab.research.google.com/github/CienciaDatosUdea/002_EstudiantesAprendizajeEstadistico/blob/main/semestre2025-2/Laboratorios/Laboratorio_04_reg_multivariada_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p>
# <h1><b><center></center></b></h1>
# <img alt="Colaboratory logo" height="300px" src="https://upload.wikimedia.org/wikipedia/commons/archive/f/fb/20161010213812%21Escudo-UdeA.svg" align="left" hspace="10px" vspace="0px">
# </p>
# <h1><b><center>Análisis Estadístico</center></b></h1>
# <h2><b><center>Prof. Hernán Salinas & Olga Lopez</center></b></h1>
# <h2><b><center> Laboratorio 4</center></b><h2>
# <h3><b><center> Regresión Multivariada </center></b><h3>
# <h5><center><b>Asignada</b>: Jueves 16 de octubre 2025</center><h5>
# <h5><center><b>Entrega</b>: Jueves 23 de octubre 2025 </center><h5>

# %% [markdown]
# <hr/>
# <b>Nombre</b>: Karen Cárdenas Solano
# <br/>
# <b>Cédula</b>: 1007731826
# <br/>
# <b>Última actualización</b>: 22 Octubre, 2025
# <hr/>

# %% [markdown]
# # Regresion multivariada
#
# Supongamos que tenemos un conjunto de caracteristicas $X = X_1,X_2...X_j...X_n$ para realizar una  predicción $y$ con valores esperados $\hat{y}$.
#
# Cada X, puede ser escrito como:
#  $X_1 = x_1^{(1)},x_1^{(2)}, x_1^{(3)}...x_1^{(m)}$,
#
#  $X_2 = x_2^{(1)},x_2^{(2)}, x_2^{(3)}...x_2^{(m)}$,
#
#  .
#
#  .
#
#  .
#
#  $X_n = x_n^{(1)},x_n^{(2)}, x_n^{(3)}...x_n^{(m)}$.
#
#
# Siendo n el número de caracteristicas y m el número de datos de datos,
# $\hat{y} = \hat{y}_1^{(1)}, \hat{y}_1^{(2)}...\hat{y}_1^{(m)} $, el conjunto de datos etiquetados  y $y = y_1^{(1)}, y_1^{(2)}...y_1^{(m)} $ los valores predichos por un modelo
#
#
#
#
# Lo anterior puede ser resumido  como:
#
#
#
# |Training|$\hat{y}$      | X_1  | X_2  |  .  | .|. |. | X_n|
# |--------|-------|------|------|-----|--|--|--|----|
# |1|$\hat{y}_1^{1}$ | $x_1^{1}$|$x_2^{1}$| .  | .|. |. | $x_n^{1}$|
# |2|$\hat{y}_1^{2}$ | $x_1^{2}$|$x_2^{2}$| .  | .|. |. | $x_n^{2}$|
# |.|.         | .        |.| .  | .|. |. | |
# |.|.         | .        |.| .  | .|. |. | |
# |.|.         | .        |.| .  | .|. |. | |
# |m|$\hat{y}_1^{m}$ | $x_1^{m}$  |$x_2^{m}$| .  | .|. |. | $x_n^{m}$|
#
#
# y el el modelo puede ser ajustado como sigue:
#
# Para un solo conjunto de datos de entrenamiento tentemos que:
#
# $y = h(\theta_0,\theta_1,\theta_2,...,\theta_n ) = \theta_0 + \theta_1 x_1+\theta_2 x_2 + \theta_3 x_3 +...+ \theta_n x_n $.
#
# \begin{equation}
# h_{\Theta}(x) = [\theta_0,\theta_1,...,\theta_n ]
# \begin{bmatrix}
# 1\\
# x_1\\
# x_2\\
# .\\
# .\\
# .\\
# x_n\\
# \end{bmatrix} = {\Theta^T X}
# \end{equation}
#
#
#
# Para todo el conjunto de datos, tenemos que:
#
# Sea $\Theta^T = [\theta_0,\theta_1,\theta_2,...,\theta_n]$ una matrix $1 \times (n+1)$ y
#
#
# \begin{equation}
# X =
# \begin{bmatrix}
# 1& 1 & 1 & .&.&.&1\\
# x_1^{(1)}&x_2^{(1)} & x_3^{(1)} & .&.&.&x_m^{1}\\
# .&. & . &.&.&.& .\\
# .&. & . & .&.&.&.\\
# .&. & . & .&.&.&.\\
# x_1^{(n+1)}&x_2^{(n+1)} & x_3^{(n+1)} & .&.&.&x_m^{(n+1)}\\
# \end{bmatrix}_{(n+1) \times m}
# \end{equation}
#
#
#
#
# luego $h = \Theta^{T} X $ con dimension $1\times m$
#
#
#
#
# La anterior ecuación, es un hiperplano en $\mathbb{R}^n$. Notese que en caso de tener una sola característica, la ecuación puede ser análizada según lo visto en la sesión de regresion lineal.
#
#
# Para la optimización, vamos a definir la función de coste **$J(\theta_1,\theta_2,\theta_3, ...,\theta_n )$** , como la función  asociada a la minima distancia entre dos puntos, según la metrica euclidiana.
#
# - Metrica Eculidiana
#
# \begin{equation}
# J(\theta_1,\theta_2,\theta_3, ...,\theta_n )=\frac{1}{2m} \sum_{i=1}^m ( h_{\Theta} (X)-\hat{y}^{(i)})^2 =\frac{1}{2m} \sum_{i = 1}^m (\Theta^{T} X - \hat{y}^{(i)})^2
# \end{equation}
#
# Otras métricas pueden ser definidas como sigue en la siguiente referencia.  [Metricas](https://jmlb.github.io/flashcards/2018/04/21/list_cost_functions_fo_neuralnets/).
#
# Nuestro objetivo será encontrar los valores mínimos
# $\Theta = \theta_0,\theta_1,\theta_2,...,\theta_n$ que minimizan el error, respecto a los valores etiquetados y esperados $\hat{y}$
#
#
# Para encontrar $\Theta$ optimo, se necesita  minimizar la función de coste, que permite obtener los valores más cercanos,  esta minimización podrá ser realizada a través de diferentes metodos, el más conocido es el gradiente descendente.

# %% [markdown]
# ## Gradiente descendente
#
# Consideremos la función de coste sin realizar el promedio  de funcion de coste:
# \begin{equation}
# \Lambda^T =
# \begin{bmatrix}
# (\theta_0 1 + \theta_1 x_1^1+\theta_2 x_2^2 + \theta_3 x_3^3 +...+ \theta_n x_n^n - \hat{y}^{1})^2 \\
# (\theta_0 1+ \theta_1 x_1^1+\theta_2 x_2^2 + \theta_3 x_3^3 +...+ \theta_n x_n^n - \hat{y}^{2})^2\\
# .\\
# .\\
# .\\
# (\theta_0 1 + \theta_1 x_1^m+\theta_2 x_2^m + \theta_3 x_3^m +...+ \theta_n x_n^m - \hat{y}^{m})^2\\
# \end{bmatrix}
# \end{equation}
#
# $\Lambda= [\Lambda_1,\Lambda_2, ...,\Lambda_m]$
#
# $J = \frac{1}{2m} \sum_{i}^m \Lambda_i $
#
# El gradiente descente, puede ser escrito como:
#
# \begin{equation}
# \Delta \vec{\Theta} =  - \alpha \nabla J(\theta_0, \theta_1,...,\theta_n)
# \end{equation}
#
# escogiendo el valor j-esimo tenemos que:
#
# \begin{equation}
# \theta_j :=  - \alpha \frac{\partial J(\theta_0, \theta_1,...\theta_j...,\theta_n)}{\partial \theta_j}
# \end{equation}
#
# Aplicando lo anterior a a función de coste asociada a la métrica ecuclidiana, tenemos que:
#
# Para $j = 0$,
#
#
# \begin{equation}
# \theta_0 :=  - \alpha \frac{\partial J(\theta_0, \theta_1,...\theta_j...,\theta_n)}{\partial \theta_0} = \frac{1}{m}\alpha \sum_{i=1}^m (\theta_j X_{ji} - \hat{y}^{(i)}) 1
# \end{equation}
#
#
#
# Para $0<j<n $
#
# \begin{equation}
# \theta_j :=  - \alpha \frac{\partial J(\theta_0, \theta_1,...\theta_j...,\theta_n)}{\partial \theta_j} = \frac{1}{m} \alpha\sum_{i=1}^m (\theta_{j} X_{ji} - \hat{y}^{(i)}) X_j
# \end{equation}
#
# donde X_j es el vector de entrenamiento j-esimo.
#
# Lo  anterior puede ser generalizado como siguem, teniendo presente que $X_0 = \vec{1}$
#
#
# Para $0\leq j<n$,
#
# \begin{equation}
# \theta_j :=  - \alpha \frac{\partial J(\theta_0, \theta_1,...\theta_j...,\theta_n)}{\partial \theta_j} = \frac{1}{m} \alpha\sum_{i=1}^m (\theta_j X_{ji} - \hat{y}^{(i)}) X_j
# \end{equation}
#
#
#
# # Vectorizando el grandiente descendete, tenemos que:
# \begin{equation}
# \nabla J = \Lambda^T X
# \end{equation}
#
# Luego:
#
# \begin{equation}
# \Theta=\Theta-\alpha \nabla J
# \end{equation}

# %% [markdown]
# # Laboratorio 04
# Objetivo: Programar una regresión multivariada
#
#
# 1. Para simular un conjunto de características $x_1$ , $x_2$,..., $x_n$ trabajaremos en la primera parte con dos características de datos aleatorios que presentan un plano y mostraremos que los párametros optimizados se corresponden con el valor esperado.
#
# - Definir la ecuación  $y = 2.1*x_1 - 3.1*x_2$, y generar números aleatorios que pertenecen al plano.
#
# - Realizar un diagrama 3D de los puntos generados aleatoriamente.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1. --- Definición del plano---

# Coeficientes
a = 2.1
b = 3.1

# Rango de valores
x_range = np.linspace(-1,1,100)
y_range = np.linspace(-1,1,100)

# Se crea la malla
X, Y = np.meshgrid(x_range, y_range)

# Valores de Z en la malla
Z_plane = a * X + b * Y

# 2. --- Generar puntos aleatorios ---
m = 100

# Datos aleatorios en el mismo rango de la malla
x1 = np.random.uniform(x_range.min(), x_range.max(), size=(m, 1))
x2 = np.random.uniform(y_range.min(), y_range.max(), size=(m, 1))

y = a * x1 + b * x2     # Ecuación

# 3. --- Gráfico en 3D ---
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z_plane, alpha=0.2, color='red')  # Plano
ax.scatter(x1, x2, y, c='blue', marker='o', alpha=0.6
           , label='Puntos Aleatorios') # Puntos aleatorios
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$y$')
ax.set_title('Puntos Aleatorios en un plano')
# Out:
# Text(0.5, 0.92, 'Puntos Aleatorios en un plano')

# %% [markdown]
# Nuestro objetivo será encontrar los valores $\theta_0 = 0, \theta_1=2.1, \theta_2=3.1$ que mejor ajustar el plano, empleando cálculos vectorizados.
#
# 2. Inicializar conjunto de parámetros $\Theta$ de manera aleatoria.

# %% [markdown]
# ---
# ***Explicación y Conceptos clave***
#
# **Matriz de características X**
#
# Para realizar cálculos vectorizados (que son mucho más rápidos en Python/NumPy), la ecuación de la hipótesis $h_\Theta(x)$ debe escribirse como un producto de matrices:
#
# $$h_{\Theta}(x) = \theta_0 + \theta_1 x_1 + \theta_2 x_2 = \mathbf{X} \cdot \mathbf{\Theta}$$
#
# - X (Matriz de Diseño): Tiene dimensiones $(m,n+1)$, donde $m$ es el número de ejemplos y $n+1$ es el número de parámetros.
#
#     - La primera columna se llena con unos para que, al multiplicar por $θ_0$, se obtenga el término del intercepto (sesgo), incluso si tu valor objetivo es 0.
#
# - Θ (Vector de Parámetros): Tiene dimensiones $(n+1,1)$.
#
#
# **Inicialización de $\Theta$**
#
# - Se inicializa theta como un vector de $(3, 1)$ con valores aleatorios.
#
# - Es una práctica estándar en el aprendizaje automático inicializar los parámetros con valores aleatorios (cercanos a cero, pero no cero) para romper la simetría y permitir que el algoritmo de optimización (como el Descenso del Gradiente) explore de manera efectiva el espacio de soluciones.
#
# ---

# %%
print(f"Dimensiones de x1: {x1.shape}")
print(f"Dimensiones de x2: {x2.shape}")
print(f"Dimensiones de y: {y.shape}")
# Out:
# Dimensiones de x1: (100, 1)
# Dimensiones de x2: (100, 1)
# Dimensiones de y: (100, 1)

# %%
n_features = 2

n_parameters = n_features + 1

Theta = np.random.randn(n_parameters, 1)

print("Número de parámetros (incluyendo el intercepto):", n_parameters)
print("Vector de parámetros inicial Theta:")
print(Theta)

# Accediendo a los parámetros individuales:
theta_0_initial = Theta[0, 0]
theta_1_initial = Theta[1, 0]
theta_2_initial = Theta[2, 0]

print(f"\nTheta_0 (Intercepto inicial): {theta_0_initial:.4f}")
print(f"Theta_1 (Pendiente x1 inicial): {theta_1_initial:.4f}")
print(f"Theta_2 (Pendiente x2 inicial): {theta_2_initial:.4f}")
# Out:
# Número de parámetros (incluyendo el intercepto): 3
# Vector de parámetros inicial Theta:
# [[ 0.32416635]
#  [-0.13014305]
#  [ 0.09699596]]
#
# Theta_0 (Intercepto inicial): 0.3242
# Theta_1 (Pendiente x1 inicial): -0.1301
# Theta_2 (Pendiente x2 inicial): 0.0970

# %% [markdown]
# 3. Construir la matrix X con dimensiones $(n+1, m)$, m es el numero de datos de entrenamiento y (n) el número de caracteristicas.

# %% [markdown]
# ---
# A continuación, se ajusta la construcción de la matriz $\mathbf{X}$ a las dimensiones solicitadas ($(n+1, m)$) y se implementa la función de coste $J(\Theta)$ usando álgebra lineal vectorizada en Python.
#
# ---

# %%
# import numpy as np

# # --- Datos generados en el punto 1 del laboratorio ---
# m = 100 # Número de datos de entrenamiento
# a = 2.1
# b = 3.1
# x1 = np.random.uniform(-1, 1, size=(m, 1)) # Dimensión (100, 1)
# x2 = np.random.uniform(-1, 1, size=(m, 1)) # Dimensión (100, 1)
# y = a * x1 + b * x2

# --- Construcción de la Matriz X (n+1, m) ---

# 1. Intercepto (theta_0)
intercepto_fila = np.ones((1, m)) # Dimensión (1, 100)

# 2. Transponer vectores (1,100)
x1_fila = x1.T
x2_fila = x2.T

X_matrix = np.vstack((intercepto_fila, x1_fila, x2_fila))

# --- Verificación de las dimensiones ---
print("Dimensión de los datos de entrenamiento (m):", m)
print("Dimensión de la Matriz X solicitada (n+1, m):", X_matrix.shape)
print(f"X tiene {X_matrix.shape[0]} filas (parámetros) y {X_matrix.shape[1]} columnas (ejemplos).")

# Ejemplo de las primeras 5 columnas (ejemplos) de la Matriz X
print("\nPrimeros 5 ejemplos (columnas) de la matriz X:")
print(X_matrix[:, :5])
# Out:
# Dimensión de los datos de entrenamiento (m): 100
# Dimensión de la Matriz X solicitada (n+1, m): (3, 100)
# X tiene 3 filas (parámetros) y 100 columnas (ejemplos).
#
# Primeros 5 ejemplos (columnas) de la matriz X:
# [[ 1.          1.          1.          1.          1.        ]
#  [-0.98987683 -0.6783839   0.09746758  0.3837904   0.30392252]
#  [ 0.59037239 -0.4583355  -0.12205716 -0.84308724 -0.94929851]]

# %% [markdown]
# 4. Calcular la función de coste(revise cuidosamente las dimensiones de cada matriz):
#
#   - $h = \Theta^{T} X $
#   - $\Lambda= (h -Y) $
#   - $\Lambda*= (h -Y)^2 $
#   - $\Lambda= [\Lambda_1,\Lambda_2, ...,\Lambda_m]$
#   - $J = \frac{1}{2m} \sum_{i}^m \Lambda_i $
#
# 5. Aplicar el gradiente descendente:
#   - Encontrar el gradiente.
#     $\nabla J = \Lambda X.T$
#
#   - Actualizar los nuevos parametros:
#     $\Theta_{n+1}=\Theta_{n}-\alpha\nabla J$
#
#
# 6. Iterar para encontrar los valores $\Theta$ que se ajustan el plano.

# %%
# 4. Funcion de coste

def calcular_coste_multivariado(X, Y, Theta):
    """
    Calcula la función de coste J(Theta) para la regresión multivariada.

    Dimensiones:
    X: (n+1, m) -> (3, 100)
    Y: (m, 1) -> (100, 1)
    Theta: (n+1, 1) -> (3, 1)
    """
    m = X.shape[1] # Número de ejemplos

    # 1. Hipotesis
    h = Theta.T @ X

    # 2. Error (Lambda)
    Error = h.T - Y

    # 3. Función de Coste J
    J = (1 / (2 * m)) * (Error.T @ Error)

    return J[0, 0]   # Valor escalar

Y_vector = y.reshape(m, 1)  # Dimensión correcta

# Inicializar theta
np.random.seed(42)
Theta_inicial = np.random.randn(3, 1)

coste_inicial = calcular_coste_multivariado(X_matrix, Y_vector, Theta_inicial)
print(f"Coste Inicial con parámetros aleatorios: {coste_inicial:.4f}")
# Out:
# Coste Inicial con parámetros aleatorios: 1.7344

# %%
# 5. Gradiente descendiente
def descenso_gradiente_multivariado(X, Y, Theta, alpha, max_iter):
    m = X.shape[1]
    historial_coste = []

    for i in range(max_iter):
        # 1. Hipotesis
        h = Theta.T @ X

        # 2. Error
        Error_grad = h.T - Y

        # 3. Gradiente (nabla J)
        nabla_J = (1 / m) * (X @ Error_grad)

        # 4. Actualizar los nuevos parámetros
        Theta = Theta - alpha * nabla_J

        coste_actual = calcular_coste_multivariado(X, Y, Theta)
        historial_coste.append(coste_actual)

    return Theta, historial_coste

# %%
#6. Iterar para Encontrar los Parámetros $\Theta$
# Parámetros
alpha_gd = 0.01      # Tasa de aprendizaje
max_iter_gd = 1000   # Número de iteraciones

# Inicialización
Theta_final, historial_coste = descenso_gradiente_multivariado(
    X_matrix, Y_vector, Theta_inicial.copy(), alpha_gd, max_iter_gd)

# Resultados
print("\n--- Resultados de la Regresión Multivariada (GD) ---")
print(f"Iteraciones completadas: {max_iter_gd}")
print(f"Tasa de Aprendizaje (alpha): {alpha_gd}")
print(f"Coste Final (J): {historial_coste[-1]:.6e}")

print("\nParámetros Theta Finales (Optimizados):")
print(f"Theta_0 (Intercepto): {Theta_final[0, 0]:.4f}")
print(f"Theta_1 (Pendiente x1): {Theta_final[1, 0]:.4f}")
print(f"Theta_2 (Pendiente x2): {Theta_final[2, 0]:.4f}")

print("\nValores Esperados:")
print("Theta_0 (Intercepto): 0.0000")
print("Theta_1 (Pendiente x1): 2.1000")
print("Theta_2 (Pendiente x2): 3.1000")

# Gráfico
plt.figure(figsize=(8, 5))
plt.plot(historial_coste, color='purple')
plt.title('Descenso de la Función de Coste J(Theta)')
plt.xlabel('Iteraciones')
plt.ylabel('Coste J')
plt.grid(True)
plt.show()
# Out:
# --- Resultados de la Regresión Multivariada (GD) ---
# Iteraciones completadas: 1000
# Tasa de Aprendizaje (alpha): 0.01
# Coste Final (J): 4.403720e-03
#
# Parámetros Theta Finales (Optimizados):
# Theta_0 (Intercepto): 0.0069
# Theta_1 (Pendiente x1): 1.9672
# Theta_2 (Pendiente x2): 2.9893
#
# Valores Esperados:
# Theta_0 (Intercepto): 0.0000
# Theta_1 (Pendiente x1): 2.1000
# Theta_2 (Pendiente x2): 3.1000

# %% [markdown]
# 7. Reescribir su código como una clase (ver ayuda)

# %%
# ** (Ayuda) **
# class MultilinearRegresion():
#   def __init__(self, X, Y):
#     self.X = #...
#     self.Y = #...
#     Nfeatures = #...
#     m = #....
#     self.theta = np.random.random(Nfeatures).reshape(Nfeatures, 1)

#   def model(self):
#     self.h = #...

#   def costo(self):
#     self.J =  #....

#   def update_params(self, learning_rate):
#     """
#     Gradiente descendente
#     """
#     grad = #...
#     self.theta = #...

#   def fit(self, learning_rate):
#     for i in range(0, 100):
#       self.model()
#       self.costo()
#       self.update_params(learning_rate)

# %%
import numpy as np
import matplotlib.pyplot as plt

class MultilinearRegresion:
    def __init__(self, X, Y):
        """
        Inicializa la clase con los datos y los parámetros Theta.

        Dimensiones esperadas:
        X: (n+1, m) -> (3, 100)
        Y: (m, 1) -> (100, 1)
        """
        self.X = X
        self.Y = Y
        self.m = X.shape[1]
        n_parameters = X.shape[0]

        # Inicialización aleatoria
        self.theta = np.random.randn(n_parameters, 1)

        # Historial de coste para seguimiento
        self.historial_coste = []

    def model(self):
        """
        Calcula la hipótesis (predicciones) h = Theta.T @ X
        Dimensión: (1, n+1) @ (n+1, m) -> (1, m)
        """
        self.h = self.theta.T @ self.X

    def costo(self):
        """
        Calcula la función de coste J = (1 / 2m) * (h.T - Y).T @ (h.T - Y)
        """
        Error = self.h.T - self.Y  # Dimensión: (m, 1)

        # J = (1 / 2m) * Error.T @ Error
        self.J = (1 / (2 * self.m)) * (Error.T @ Error)[0, 0]
        self.historial_coste.append(self.J)

    def update_params(self, learning_rate):
        """
        Aplica el Descenso del Gradiente.
        nabla J = (1/m) * X @ Error
        Theta_new = Theta_old - alpha * nabla J
        """
        # Error (m,1)
        Error_grad = self.h.T - self.Y

        # Gradiente
        nabla_J = (1 / self.m) * (self.X @ Error_grad)

        # Actualizar Theta
        self.theta = self.theta - learning_rate * nabla_J

    def fit(self, learning_rate, max_iter=100):
        """
        Ejecuta el proceso de entrenamiento.
        """
        print(f"Iniciando entrenamiento con alpha={learning_rate} y {max_iter} iteraciones...")
        print(f"Theta inicial: {self.theta.T[0]}")

        for i in range(max_iter):
            self.model()
            self.costo()
            self.update_params(learning_rate)

        print("\n--- Entrenamiento Finalizado ---")
        print(f"Coste final (J): {self.J:.6e}")
        print(f"Theta final: {self.theta.T[0]}")
        return self.theta, self.historial_coste

# Datos de prueba
m = 100
a = 2.1
b = 3.1
x1 = np.random.uniform(-1, 1, size=(m, 1))
x2 = np.random.uniform(-1, 1, size=(m, 1))
y_data = a * x1 + b * x2

# Crear la Matriz X (n+1, m) y el vector Y (m, 1)
X_data = np.vstack((np.ones((1, m)), x1.T, x2.T))
Y_data = y_data.reshape(m, 1)

# Uso de Clase
regresion = MultilinearRegresion(X_data, Y_data)

# Entrenar el modelo
alpha_test = 0.01
max_iters = 500
theta_optimo, coste_historial = regresion.fit(learning_rate=alpha_test, max_iter=max_iters)

# Visualización del Descenso del Coste
plt.figure(figsize=(8, 5))
plt.plot(coste_historial, color='green')
plt.title('Descenso de la Función de Coste J(Theta) - Orientado a Objetos')
plt.xlabel(f'Iteraciones (Máx: {max_iters})')
plt.ylabel('Coste J')
plt.grid(True)
plt.show()

# Comparación
print("\n--- Comparación Final ---")
print(f"Valores Reales (sin ruido): [0.0, 2.1, 3.1]")
print(f"Valores Optenidos:          [{theta_optimo[0, 0]:.4f}, {theta_optimo[1, 0]:.4f}, {theta_optimo[2, 0]:.4f}]")
# Out:
# Iniciando entrenamiento con alpha=0.01 y 500 iteraciones...
# Theta inicial: [ 1.52302986  0.29307247 -0.71435142]
#
# --- Entrenamiento Finalizado ---
# Coste final (J): 1.012162e-01
# Theta final: [-0.02876388  1.75637518  2.40488062]
# --- Comparación Final ---
# Valores Reales (sin ruido): [0.0, 2.1, 3.1]
# Valores Optenidos:          [-0.0288, 1.7564, 2.4049]
