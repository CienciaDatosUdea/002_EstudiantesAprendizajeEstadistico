# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# %% [markdown]
# 1.

# %%
digits = load_digits()
print(digits.data.shape)
plt.gray()
plt.matshow(digits.images[1796])
plt.show()
# Out:
# (1797, 64)

# %% [markdown]
# 2.

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(digits.data, digits.target)

print(clf.predict(digits.data[-10:]))
print(digits.target[-10:])
print(clf.feature_importances_)
print(len(clf.feature_importances_))
# Out:
# [5 4 8 8 4 9 0 8 9 8]
# [5 4 8 8 4 9 0 8 9 8]
# [0.00000000e+00 2.33942527e-03 2.23009552e-02 1.01350444e-02
#  9.14044203e-03 1.87852880e-02 9.59780686e-03 5.11548071e-04
#  1.75273856e-05 1.11994828e-02 2.62312305e-02 6.84929947e-03
#  1.60308567e-02 2.52473482e-02 5.66992727e-03 6.17821538e-04
#  6.59787722e-05 8.09924606e-03 1.87637902e-02 2.34662793e-02
#  2.76619792e-02 5.05975667e-02 9.85165087e-03 2.60776228e-04
#  0.00000000e+00 1.59236200e-02 4.45805310e-02 2.66509286e-02
#  2.82502007e-02 2.42436877e-02 2.83155755e-02 3.45526330e-05
#  0.00000000e+00 3.41307674e-02 2.75562615e-02 1.79334389e-02
#  4.12793707e-02 1.72602045e-02 2.60232663e-02 0.00000000e+00
#  0.00000000e+00 1.13368547e-02 3.76725861e-02 4.73853489e-02
#  2.20258688e-02 1.67696331e-02 1.75130972e-02 5.32137657e-05
#  1.48446352e-05 1.90676741e-03 1.64391403e-02 2.46340010e-02
#  1.62082390e-02 2.46207440e-02 2.62796873e-02 1.80788259e-03
#  1.20652196e-05 1.86201724e-03 1.81716348e-02 9.08749312e-03
#  2.72207005e-02 1.94090250e-02 1.96671113e-02 4.27836754e-03]
# 64
